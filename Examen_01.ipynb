# %% [markdown]
# *Braulio Gabriel López Parada
# 2SV1*

# %% [markdown]
# Este programa calcula las raíces de ax^2 + bx + c

# %%
a = float(input("INGRESE VALOR DE a: "))
while a == 0:
  a = float(input("INGRESE VALOR DE a DISTINTO A CERO: "))
b = float(input("INGRESE VALOR DE b: "))
c = float(input("INGRESE VALOR DE c: "))
print("a=", a, "  b=", b, "  c=", c)
dis = ((b**2)-(4*a*c))
while dis < 0:
  print("DISCRIMINANTE: ", dis)
  print(False, ", EL DISCRIMINANTE DEBE SER POSITIVO")
  a = float(input("INGRESE VALOR DE a: "))
  while a == 0:
    a = float(input("INGRESE VALOR DE a DISTINTO A CERO: "))
  b = float(input("INGRESE VALOR DE b: "))
  c = float(input("INGRESE VALOR DE c: "))
  print("a=", a, "  b=", b, "  c=", c)
  dis = ((b**2)-(4*a*c))
x1 = (((-b)+(dis**(1/2)))/(a*2))
print("x1 = ", x1)
x2 = (((-b)-(dis**(1/2)))/(a*2))
print("x2 = ", x2)

# %% [markdown]
# Este programa calcula el valor de f(x) = *e*^-x

# %%
Lista=[]
def Función(x, e=2.7182818284):
  cont = -5
  while cont < 10:
    cont = cont + 1
    f = e**(-cont)
    Lista.append(f)
    if f < 0.0025:
      break
    print(Lista)
  f = e**(-x)
  print("RESULTADO = ", f)
  while x != 123:
    x = int(input("INGRESE VALOR X: "))
    f = e**(-x)
    print("RESULTADO = ", f)
  
x = int(input("INGRESE VALOR X: "))

Función(x)
